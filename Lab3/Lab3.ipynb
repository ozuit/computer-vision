# %%
# load thư viện
from matplotlib import pyplot as plt
import cv2
# load cascade
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
# load image
img = cv2.imread('vietnam.jpg')
# chuyen thanh anh muc xam
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# chuyen thanh anh RGB de show cho dung mau sac
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
# luu cac khuon mat xuong may
id = 1
for (x, y, w, h) in faces:
    fileName = "face."+str(id)+ ".jpg"
    cv2.imwrite(fileName, img[y:y+h, x:x+w])
    id = id + 1

# %%
# ve rectangle cac khuon mat trong hinh
faces = face_cascade.detectMultiScale(gray, 1.3, 3)
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)
# show ket qua
plt.axis('off')
plt.rcParams["figure.figsize"] = (46, 46)
plt.imshow(img)
plt.show()

# %%
from IPython.core.display import display, HTML

[display(HTML(f'<img src="face.{i}.jpg" width="100" />')) for i in range(1, id)]
# Out:
# <img src="face.1.jpg" width="100" />
# <img src="face.2.jpg" width="100" />
# <img src="face.3.jpg" width="100" />
# <img src="face.4.jpg" width="100" />
# <img src="face.5.jpg" width="100" />
# <img src="face.6.jpg" width="100" />
# <img src="face.7.jpg" width="100" />
# <img src="face.8.jpg" width="100" />
# <img src="face.9.jpg" width="100" />
# <img src="face.10.jpg" width="100" />
# <img src="face.11.jpg" width="100" />
# [None, None, None, None, None, None, None, None, None, None, None]
